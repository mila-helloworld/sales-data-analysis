# %% [markdown]
# # Sales Data Analysis
#
# This project explores a mock sales dataset generated with Mockaroo.
# We’ll perform exploratory data analysis (EDA) and visualize sales trends
# by region, category, and product.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sales_data.csv")

print(df.head())
print(df.info())
print(df.describe())

sales_region = df.groupby("region")["revenue"].sum()
sales_region.plot(kind="bar", title="Total Sales by Region")
plt.show()

sales_category = df.groupby("category")["revenue"].sum()
sales_category.plot(kind="bar", title="Total Sales by Category")
plt.show()

sales_product = df.groupby("product")["revenue"].sum().sort_values(ascending=False)
sales_product.plot(kind="bar", title="Total Sales by Product")
plt.show()
# Out:
#    order_id  order_date first_name last_name     product     category region  \
# 0         1   8/10/2025       Geri   Goullee      Laptop  Electronics   East
# 1         2  10/31/2024      Matti   Chapell  Smartphone  Accessories  South
# 2         3    7/8/2025       Ethe   Taberer  Headphones  Electronics  South
# 3         4  10/30/2024    Jo-anne     Coche  Desk Chair    Furniture   West
# 4         5   3/30/2025     Harris   Colloff     Printer  Accessories  South
#
#    quantity  unit_price  revenue
# 0         3     1395.08  4185.24
# 1         1     1790.34  1790.34
# 2         4       60.95   243.80
# 3         3      740.85  2222.55
# 4         2      514.09  1028.18
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    1000 non-null   int64
#  1   order_date  1000 non-null   object
# ...

# %%
df = pd.read_csv("sales_data.csv")

# %%
import pandas as pd
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    order_id  order_date first_name last_name     product     category region  \
# 0         1   8/10/2025       Geri   Goullee      Laptop  Electronics   East
# 1         2  10/31/2024      Matti   Chapell  Smartphone  Accessories  South
# 2         3    7/8/2025       Ethe   Taberer  Headphones  Electronics  South
# 3         4  10/30/2024    Jo-anne     Coche  Desk Chair    Furniture   West
# 4         5   3/30/2025     Harris   Colloff     Printer  Accessories  South
#
#    quantity  unit_price  revenue
# 0         3     1395.08  4185.24
# 1         1     1790.34  1790.34
# 2         4       60.95   243.80
# 3         3      740.85  2222.55
# 4         2      514.09  1028.18

# %% [markdown]
# ## Data Overview
# We begin by checking column names, data types, and dataset structure.

# %%
# Check column names & data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    1000 non-null   int64
#  1   order_date  1000 non-null   object
#  2   first_name  1000 non-null   object
#  3   last_name   1000 non-null   object
#  4   product     1000 non-null   object
#  5   category    1000 non-null   object
#  6   region      1000 non-null   object
#  7   quantity    1000 non-null   int64
#  8   unit_price  1000 non-null   float64
#  9   revenue     1000 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 78.3+ KB
# None

# %% [markdown]
# ## Summary Statistics
# Here we review summary statistics for numeric columns (unit price, quantity, revenue).

# %%
# Summary statistics for numeric columns
print(df.describe())
# Out:
#           order_id     quantity  unit_price       revenue
# count  1000.000000  1000.000000  1000.00000   1000.000000
# mean    500.500000     5.500000  1039.82933   5639.347970
# std     288.819436     2.840434   561.47038   4466.890465
# min       1.000000     1.000000    51.77000     82.980000
# 25%     250.750000     3.000000   568.49500   1884.032500
# 50%     500.500000     5.000000  1040.29500   4530.270000
# 75%     750.250000     8.000000  1542.12500   8212.350000
# max    1000.000000    10.000000  1993.11000  19814.900000

# %% [markdown]
# ## Missing Values
# Check if there are any missing values in the dataset.

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# order_id      0
# order_date    0
# first_name    0
# last_name     0
# product       0
# category      0
# region        0
# quantity      0
# unit_price    0
# revenue       0
# dtype: int64

# %% [markdown]
# ## Sales by Region
# We aggregate total revenue by region to see where sales are strongest.

# %%
# Total revenue by region
sales_region = df.groupby("region")["revenue"].sum()
sales_region.plot(kind="bar", title="Total Sales by Region")
plt.show()

# %% [markdown]
# ## Sales by Category
# We compare revenue contributions across product categories.

# %%
# Total revenue by category
sales_category = df.groupby("category")["revenue"].sum()
sales_category.plot(kind="bar", title="Total Sales by Category")
plt.show()

# %% [markdown]
# ## Top Products by Revenue
# Identify the top 10 products driving the highest revenue.

# %%
# Top 10 products by revenue
top_products = df.groupby("product")["revenue"].sum().sort_values(ascending=False).head(10)
top_products.plot(kind="bar", title="Top 10 Products by Revenue")
plt.show()
